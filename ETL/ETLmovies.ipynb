# %%
import pandas as pd
import ast
import numpy as np

# %%
#charge and shape of the dataset
url='https://drive.google.com/file/d/1Rp7SNuoRnmdoQMa5LWXuK4i7W1ILblYb/view?usp=drive_link'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2] 
df=pd.read_csv(url)
df.shape
# Out:
# C:\Users\Cristian Nicolás\AppData\Local\Temp\ipykernel_7020\2576785862.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('movies_dataset.csv')
# (45466, 24)

# %%
#we copy and save, then drop colums we will not use
df_removed_columns = df[['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage']].copy()
df_droped=df.drop(['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage'], axis=1)
df_removed_columns.shape
# Out:
# (45466, 6)

# %%
df_droped.shape
# Out:
# (45466, 18)

# %%
def extract_attribute(row, attribute):
    try:
        collection = ast.literal_eval(row)
        if isinstance(collection, dict):
            return collection.get(attribute, np.nan)
    except (SyntaxError, ValueError):
        pass
    return np.nan

df_droped['collection_id'] = df_droped['belongs_to_collection'].apply(lambda row: extract_attribute(row, 'id'))
df_droped['collection_name'] = df_droped['belongs_to_collection'].apply(lambda row: extract_attribute(row, 'name'))
df_droped['collection_poster_path'] = df_droped['belongs_to_collection'].apply(lambda row: extract_attribute(row, 'poster_path'))
df_droped['collection_backdrop_path'] = df_droped['belongs_to_collection'].apply(lambda row: extract_attribute(row, 'backdrop_path'))

df_droped.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average vote_count  collection_id  \
# 0                    Toy Story          7.7     5415.0        10194.0
# 1                      Jumanji          6.9     2413.0            NaN
# 2             Grumpier Old Men          6.5       92.0       119050.0
# 3            Waiting to Exhale          6.1       34.0            NaN
# 4  Father of the Bride Part II          5.7      173.0        96871.0
#
#                   collection_name            collection_poster_path  \
# 0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                             NaN                               NaN
# 2       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3                             NaN                               NaN
# 4  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
#
#            collection_backdrop_path
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                               NaN
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
#
# [5 rows x 22 columns]

# %%
# we save the original colum before we drop, in case we need it later
df_removed_columns['belongs_to_collection'] = df_droped['belongs_to_collection']
df_droped.drop('belongs_to_collection', axis=1, inplace=True)
df_removed_columns.head()
# Out:
#    video    imdb_id  adult               original_title  \
# 0  False  tt0114709  False                    Toy Story
# 1  False  tt0113497  False                      Jumanji
# 2  False  tt0113228  False             Grumpier Old Men
# 3  False  tt0114885  False            Waiting to Exhale
# 4  False  tt0113041  False  Father of the Bride Part II
#
#                         poster_path                              homepage  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  http://toystory.disney.com/toy-story
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg                                   NaN
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg                                   NaN
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg                                   NaN
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg                                   NaN
#
#                                belongs_to_collection
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Col...

# %%
df_droped.head(3)
# Out:
#      budget                                             genres     id  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
# 2                en  A family wedding reignites the ancient feud be...
#
#   popularity                               production_companies  \
# 0  21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2    11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
#
#        revenue  ...                                   spoken_languages  \
# 0  373554033.0  ...           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0  ...  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0  ...           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
#
#               title vote_average  vote_count  collection_id  \
# 0         Toy Story          7.7      5415.0        10194.0
# 1           Jumanji          6.9      2413.0            NaN
# 2  Grumpier Old Men          6.5        92.0       119050.0
#
#              collection_name            collection_poster_path  \
# 0       Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                        NaN                               NaN
# 2  Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
#
#            collection_backdrop_path
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
#
# [3 rows x 21 columns]

# %%
def extract_genres(row):
    try:
        genres_list = ast.literal_eval(row)
        genres = [genre['name'] for genre in genres_list]
        return genres
    except (SyntaxError, ValueError):
        return []

df_droped['genres_extracted'] = df_droped['genres'].apply(extract_genres)

# %%
df_droped.head()
# Out:
#      budget                                             genres     id  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4         0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
# 2                en  A family wedding reignites the ancient feud be...
# 3                en  Cheated on, mistreated and stepped on, the wom...
# 4                en  Just when George Banks has recovered from his ...
#
#   popularity                               production_companies  \
# 0  21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2    11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3   3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4   8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  ...    status  \
# 0  373554033.0  ...  Released
# 1  262797249.0  ...  Released
# 2          0.0  ...  Released
# 3   81452156.0  ...  Released
# 4   76578911.0  ...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average vote_count  collection_id  \
# 0                    Toy Story          7.7     5415.0        10194.0
# 1                      Jumanji          6.9     2413.0            NaN
# 2             Grumpier Old Men          6.5       92.0       119050.0
# 3            Waiting to Exhale          6.1       34.0            NaN
# 4  Father of the Bride Part II          5.7      173.0        96871.0
#
#                   collection_name            collection_poster_path  \
# 0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                             NaN                               NaN
# 2       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3                             NaN                               NaN
# 4  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
#
#            collection_backdrop_path              genres_extracted
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg   [Animation, Comedy, Family]
# 1                               NaN  [Adventure, Fantasy, Family]
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg             [Romance, Comedy]
# 3                               NaN      [Comedy, Drama, Romance]
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg                      [Comedy]
#
# [5 rows x 22 columns]

# %%
df_removed_columns['genres'] = df_droped['genres']
df_droped.drop('genres', axis=1, inplace=True)
df_removed_columns.head()
# Out:
#    video    imdb_id  adult               original_title  \
# 0  False  tt0114709  False                    Toy Story
# 1  False  tt0113497  False                      Jumanji
# 2  False  tt0113228  False             Grumpier Old Men
# 3  False  tt0114885  False            Waiting to Exhale
# 4  False  tt0113041  False  Father of the Bride Part II
#
#                         poster_path                              homepage  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  http://toystory.disney.com/toy-story
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg                                   NaN
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg                                   NaN
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg                                   NaN
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg                                   NaN
#
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %%
df_droped.head()
# Out:
#      budget     id original_language  \
# 0  30000000    862                en
# 1  65000000   8844                en
# 2         0  15602                en
# 3  16000000  31357                en
# 4         0  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime  ...    status  \
# 0  373554033.0     81.0  ...  Released
# 1  262797249.0    104.0  ...  Released
# 2          0.0    101.0  ...  Released
# 3   81452156.0    127.0  ...  Released
# 4   76578911.0    106.0  ...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average  vote_count  collection_id  \
# 0                    Toy Story          7.7      5415.0        10194.0
# 1                      Jumanji          6.9      2413.0            NaN
# 2             Grumpier Old Men          6.5        92.0       119050.0
# 3            Waiting to Exhale          6.1        34.0            NaN
# 4  Father of the Bride Part II          5.7       173.0        96871.0
#
#                   collection_name            collection_poster_path  \
# 0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                             NaN                               NaN
# 2       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3                             NaN                               NaN
# 4  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
#
#            collection_backdrop_path              genres_extracted
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg   [Animation, Comedy, Family]
# 1                               NaN  [Adventure, Fantasy, Family]
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg             [Romance, Comedy]
# 3                               NaN      [Comedy, Drama, Romance]
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg                      [Comedy]
#
# [5 rows x 21 columns]

# %%
def extract_production_companies(row):
    try:
        companies_list = ast.literal_eval(row)
        if isinstance(companies_list, list):
            companies = [company['name'] for company in companies_list]
            return companies
        else:
            return []
    except (SyntaxError, ValueError):
        return []

df_droped['production_companies_extracted'] = df_droped['production_companies'].apply(extract_production_companies)

# %%
df_droped.head()
# Out:
#      budget     id original_language  \
# 0  30000000    862                en
# 1  65000000   8844                en
# 2         0  15602                en
# 3  16000000  31357                en
# 4         0  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime  ...  \
# 0  373554033.0     81.0  ...
# 1  262797249.0    104.0  ...
# 2          0.0    101.0  ...
# 3   81452156.0    127.0  ...
# 4   76578911.0    106.0  ...
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average vote_count  collection_id  \
# 0                    Toy Story          7.7     5415.0        10194.0
# 1                      Jumanji          6.9     2413.0            NaN
# 2             Grumpier Old Men          6.5       92.0       119050.0
# 3            Waiting to Exhale          6.1       34.0            NaN
# 4  Father of the Bride Part II          5.7      173.0        96871.0
#
#                   collection_name            collection_poster_path  \
# 0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                             NaN                               NaN
# 2       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3                             NaN                               NaN
# 4  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
#
#            collection_backdrop_path              genres_extracted  \
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg   [Animation, Comedy, Family]
# 1                               NaN  [Adventure, Fantasy, Family]
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg             [Romance, Comedy]
# 3                               NaN      [Comedy, Drama, Romance]
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg                      [Comedy]
#
#                       production_companies_extracted
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# 3           [Twentieth Century Fox Film Corporation]
# 4       [Sandollar Productions, Touchstone Pictures]
#
# [5 rows x 22 columns]

# %%
df_removed_columns['production_companies'] = df_droped['production_companies']
df_droped.drop('production_companies', axis=1, inplace=True)
df_removed_columns.head()
# Out:
#    video    imdb_id  adult               original_title  \
# 0  False  tt0114709  False                    Toy Story
# 1  False  tt0113497  False                      Jumanji
# 2  False  tt0113228  False             Grumpier Old Men
# 3  False  tt0114885  False            Waiting to Exhale
# 4  False  tt0113041  False  Father of the Bride Part II
#
#                         poster_path                              homepage  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  http://toystory.disney.com/toy-story
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg                                   NaN
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg                                   NaN
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg                                   NaN
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg                                   NaN
#
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                 production_companies
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...

# %%
def extract_prodtucion_countries(row):
    try:
        countries_list=ast.literal_eval(row)
        if isinstance(countries_list,list):
            countries=[country['name'] for country in countries_list]
            return countries
        else:
            return[]
    except(SyntaxError,ValueError):
        return[]

df_droped['production_countries_extracted']=df_droped['production_countries'].apply(extract_prodtucion_countries)

# %%
df_droped.head(10)
# Out:
#      budget     id original_language  \
# 0  30000000    862                en
# 1  65000000   8844                en
# 2         0  15602                en
# 3  16000000  31357                en
# 4         0  11862                en
# 5  60000000    949                en
# 6  58000000  11860                en
# 7         0  45325                en
# 8  35000000   9091                en
# 9  58000000    710                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
# 5  Obsessive master thief, Neil McCauley leads a ...  17.924927
# 6  An ugly duckling having undergone a remarkable...   6.677277
# 7  A mischievous young boy, Tom Sawyer, witnesses...   2.561161
# 8  International action superstar Jean Claude Van...    5.23158
# 9  James Bond must unmask the mysterious head of ...  14.686036
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# 5  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 6  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   1995-12-15
# 7  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 8  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 9  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   1995-11-16
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5  187436818.0    170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6          0.0    127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7          0.0     97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8   64350171.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9  352194034.0    130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#    ...                        title vote_average vote_count  collection_id  \
# 0  ...                    Toy Story          7.7     5415.0        10194.0
# 1  ...                      Jumanji          6.9     2413.0            NaN
# 2  ...             Grumpier Old Men          6.5       92.0       119050.0
# 3  ...            Waiting to Exhale          6.1       34.0            NaN
# 4  ...  Father of the Bride Part II          5.7      173.0        96871.0
# 5  ...                         Heat          7.7     1886.0            NaN
# 6  ...                      Sabrina          6.2      141.0            NaN
# 7  ...                 Tom and Huck          5.4       45.0            NaN
# 8  ...                 Sudden Death          5.5      174.0            NaN
# 9  ...                    GoldenEye          6.6     1194.0          645.0
#
#                   collection_name            collection_poster_path  \
# 0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                             NaN                               NaN
# 2       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3                             NaN                               NaN
# 4  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
# 5                             NaN                               NaN
# 6                             NaN                               NaN
# 7                             NaN                               NaN
# 8                             NaN                               NaN
# 9           James Bond Collection   /HORpg5CSkmeQlAolx3bKMrKgfi.jpg
#
#            collection_backdrop_path                    genres_extracted  \
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg         [Animation, Comedy, Family]
# 1                               NaN        [Adventure, Fantasy, Family]
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg                   [Romance, Comedy]
# 3                               NaN            [Comedy, Drama, Romance]
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg                            [Comedy]
# 5                               NaN    [Action, Crime, Drama, Thriller]
# 6                               NaN                   [Comedy, Romance]
# 7                               NaN  [Action, Adventure, Drama, Family]
# 8                               NaN       [Action, Adventure, Thriller]
# 9  /6VcVl48kNKvdXOZfJPdarlUGOsk.jpg       [Adventure, Action, Thriller]
#
#                       production_companies_extracted  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# 3           [Twentieth Century Fox Film Corporation]
# 4       [Sandollar Productions, Touchstone Pictures]
# 5  [Regency Enterprises, Forward Pass, Warner Bros.]
# 6  [Paramount Pictures, Scott Rudin Productions, ...
# 7                             [Walt Disney Pictures]
# 8  [Universal Pictures, Imperial Entertainment, S...
# 9                  [United Artists, Eon Productions]
#
#                production_countries_extracted
# 0                  [United States of America]
# 1                  [United States of America]
# 2                  [United States of America]
# 3                  [United States of America]
# 4                  [United States of America]
# 5                  [United States of America]
# 6         [Germany, United States of America]
# 7                  [United States of America]
# 8                  [United States of America]
# 9  [United Kingdom, United States of America]
#
# [10 rows x 22 columns]

# %%
df_removed_columns['production_countries'] = df_droped['production_countries']
df_droped.drop('production_countries', axis=1, inplace=True)
df_removed_columns.head()
# Out:
#    video    imdb_id  adult               original_title  \
# 0  False  tt0114709  False                    Toy Story
# 1  False  tt0113497  False                      Jumanji
# 2  False  tt0113228  False             Grumpier Old Men
# 3  False  tt0114885  False            Waiting to Exhale
# 4  False  tt0113041  False  Father of the Bride Part II
#
#                         poster_path                              homepage  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  http://toystory.disney.com/toy-story
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg                                   NaN
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg                                   NaN
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg                                   NaN
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg                                   NaN
#
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...

# %%
df_droped.head(3)
# Out:
#      budget     id original_language  \
# 0  30000000    862                en
# 1  65000000   8844                en
# 2         0  15602                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  ...             title vote_average  vote_count  collection_id  \
# 0  Released  ...         Toy Story          7.7      5415.0        10194.0
# 1  Released  ...           Jumanji          6.9      2413.0            NaN
# 2  Released  ...  Grumpier Old Men          6.5        92.0       119050.0
#
#              collection_name            collection_poster_path  \
# 0       Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                        NaN                               NaN
# 2  Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
#
#            collection_backdrop_path              genres_extracted  \
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg   [Animation, Comedy, Family]
# 1                               NaN  [Adventure, Fantasy, Family]
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg             [Romance, Comedy]
#
#                       production_companies_extracted  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
#
#   production_countries_extracted
# 0     [United States of America]
# 1     [United States of America]
# 2     [United States of America]
#
# [3 rows x 21 columns]

# %%
def extract_languages(row):
    try:
        languages_list=ast.literal_eval(row)
        if isinstance(languages_list,list):
            language=[language['name'] for language in languages_list]
            return language
        else:
            return[]
    except(SyntaxError,ValueError):
        return[]

df_droped['languages_extracted']=df_droped['spoken_languages'].apply(extract_languages)

# %%
df_removed_columns['spoken_languages'] = df_droped['spoken_languages']
df_droped.drop('spoken_languages', axis=1, inplace=True)
df_removed_columns.head()
# Out:
#    video    imdb_id  adult               original_title  \
# 0  False  tt0114709  False                    Toy Story
# 1  False  tt0113497  False                      Jumanji
# 2  False  tt0113228  False             Grumpier Old Men
# 3  False  tt0114885  False            Waiting to Exhale
# 4  False  tt0113041  False  Father of the Bride Part II
#
#                         poster_path                              homepage  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  http://toystory.disney.com/toy-story
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg                                   NaN
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg                                   NaN
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg                                   NaN
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg                                   NaN
#
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                                     spoken_languages
# 0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           [{'iso_639_1': 'en', 'name': 'English'}]
# 3           [{'iso_639_1': 'en', 'name': 'English'}]
# 4           [{'iso_639_1': 'en', 'name': 'English'}]

# %%
df_droped.head(4)
# Out:
#      budget     id original_language  \
# 0  30000000    862                en
# 1  65000000   8844                en
# 2         0  15602                en
# 3  16000000  31357                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495   1995-12-22
#
#        revenue  runtime    status  \
# 0  373554033.0     81.0  Released
# 1  262797249.0    104.0  Released
# 2          0.0    101.0  Released
# 3   81452156.0    127.0  Released
#
#                                              tagline  ... vote_average  \
# 0                                                NaN  ...          7.7
# 1          Roll the dice and unleash the excitement!  ...          6.9
# 2  Still Yelling. Still Fighting. Still Ready for...  ...          6.5
# 3  Friends are the people who let you be yourself...  ...          6.1
#
#    vote_count  collection_id            collection_name  \
# 0      5415.0        10194.0       Toy Story Collection
# 1      2413.0            NaN                        NaN
# 2        92.0       119050.0  Grumpy Old Men Collection
# 3        34.0            NaN                        NaN
#
#              collection_poster_path          collection_backdrop_path  \
# 0  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN                               NaN
# 2  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                               NaN                               NaN
#
#                genres_extracted  \
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]
# 3      [Comedy, Drama, Romance]
#
#                       production_companies_extracted  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# 3           [Twentieth Century Fox Film Corporation]
#
#   production_countries_extracted  languages_extracted
# 0     [United States of America]            [English]
# 1     [United States of America]  [English, Français]
# 2     [United States of America]            [English]
# 3     [United States of America]            [English]
#
# [4 rows x 21 columns]

# %%
df_removed_columns[['collection_poster_path', 'collection_backdrop_path']] = df_droped[['collection_poster_path', 'collection_backdrop_path']].copy()
df_droped = df_droped.drop(['collection_poster_path', 'collection_backdrop_path'], axis=1)

# %%
df_droped.head(3)
# Out:
#      budget     id original_language  \
# 0  30000000    862                en
# 1  65000000   8844                en
# 2         0  15602                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
#
#        revenue  runtime    status  \
# 0  373554033.0     81.0  Released
# 1  262797249.0    104.0  Released
# 2          0.0    101.0  Released
#
#                                              tagline             title  \
# 0                                                NaN         Toy Story
# 1          Roll the dice and unleash the excitement!           Jumanji
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men
#
#    vote_average  vote_count  collection_id            collection_name  \
# 0           7.7      5415.0        10194.0       Toy Story Collection
# 1           6.9      2413.0            NaN                        NaN
# 2           6.5        92.0       119050.0  Grumpy Old Men Collection
#
#                genres_extracted  \
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]
#
#                       production_companies_extracted  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
#
#   production_countries_extracted  languages_extracted
# 0     [United States of America]            [English]
# 1     [United States of America]  [English, Français]
# 2     [United States of America]            [English]

# %%
#save the df unested in a new csv
#df_droped.to_csv('D:\SoyHenry\Proyecto Integrador 1\Movies-Recomendation-ML\Data\movies_dataset_unnested.csv', index=False)

# %%
#fill the nulls values with 0(cero) in revenue and budget colums
df_droped[['revenue', 'budget']] = df_droped[['revenue', 'budget']].fillna(0)

# %%
df_droped.shape
# Out:
# (45466, 19)

# %%
df_unested = df_droped.dropna(subset=['release_date'])
df_unested.shape
df_unested.head()
# Out:
#      budget     id original_language  \
# 0  30000000    862                en
# 1  65000000   8844                en
# 2         0  15602                en
# 3  16000000  31357                en
# 4         0  11862                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495   1995-12-22
# 4  Just when George Banks has recovered from his ...   8.387519   1995-02-10
#
#        revenue  runtime    status  \
# 0  373554033.0     81.0  Released
# 1  262797249.0    104.0  Released
# 2          0.0    101.0  Released
# 3   81452156.0    127.0  Released
# 4   76578911.0    106.0  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average  vote_count  collection_id  \
# 0                    Toy Story           7.7      5415.0        10194.0
# 1                      Jumanji           6.9      2413.0            NaN
# 2             Grumpier Old Men           6.5        92.0       119050.0
# 3            Waiting to Exhale           6.1        34.0            NaN
# 4  Father of the Bride Part II           5.7       173.0        96871.0
#
#                   collection_name              genres_extracted  \
# 0            Toy Story Collection   [Animation, Comedy, Family]
# 1                             NaN  [Adventure, Fantasy, Family]
# 2       Grumpy Old Men Collection             [Romance, Comedy]
# 3                             NaN      [Comedy, Drama, Romance]
# 4  Father of the Bride Collection                      [Comedy]
#
#                       production_companies_extracted  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# 3           [Twentieth Century Fox Film Corporation]
# 4       [Sandollar Productions, Touchstone Pictures]
#
#   production_countries_extracted  languages_extracted
# 0     [United States of America]            [English]
# 1     [United States of America]  [English, Français]
# 2     [United States of America]            [English]
# 3     [United States of America]            [English]
# 4     [United States of America]            [English]

# %%
# Convert the 'release_date' column to datetime format, handling errors and invalid values
df_unested['release_date'] = pd.to_datetime(df_unested['release_date'], errors='coerce')

# Drop rows with invalid datetime values
df_unested = df_unested.dropna(subset=['release_date'])

# Extract the year and assign it to a new column 'release_year'
df_unested['release_year'] = df_unested['release_date'].dt.year
# Out:
# C:\Users\Cristian Nicolás\AppData\Local\Temp\ipykernel_7020\197744934.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unested['release_date'] = pd.to_datetime(df_unested['release_date'], errors='coerce')

# %%
df_unested
# Out:
#          budget      id original_language  \
# 0      30000000     862                en
# 1      65000000    8844                en
# 2             0   15602                en
# 3      16000000   31357                en
# 4             0   11862                en
# ...         ...     ...               ...
# 45460         0   30840                en
# 45462         0  111109                tl
# 45463         0   67758                en
# 45464         0  227506                en
# 45465         0  461257                en
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#       release_date      revenue  runtime    status  \
# 0       1995-10-30  373554033.0     81.0  Released
# 1       1995-12-15  262797249.0    104.0  Released
# 2       1995-12-22          0.0    101.0  Released
# 3       1995-12-22   81452156.0    127.0  Released
# 4       1995-02-10   76578911.0    106.0  Released
# ...            ...          ...      ...       ...
# 45460   1991-05-13          0.0    104.0  Released
# 45462   2011-11-17          0.0    360.0  Released
# 45463   2003-08-01          0.0     90.0  Released
# 45464   1917-10-21          0.0     87.0  Released
# 45465   2017-06-09          0.0     75.0  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45460                                                NaN
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count  collection_id  \
# 0                        Toy Story           7.7      5415.0        10194.0
# 1                          Jumanji           6.9      2413.0            NaN
# 2                 Grumpier Old Men           6.5        92.0       119050.0
# 3                Waiting to Exhale           6.1        34.0            NaN
# 4      Father of the Bride Part II           5.7       173.0        96871.0
# ...                            ...           ...         ...            ...
# 45460                   Robin Hood           5.7        26.0            NaN
# 45462          Century of Birthing           9.0         3.0            NaN
# 45463                     Betrayal           3.8         6.0            NaN
# 45464             Satan Triumphant           0.0         0.0            NaN
# 45465                     Queerama           0.0         0.0            NaN
#
#                       collection_name              genres_extracted  \
# 0                Toy Story Collection   [Animation, Comedy, Family]
# 1                                 NaN  [Adventure, Fantasy, Family]
# 2           Grumpy Old Men Collection             [Romance, Comedy]
# 3                                 NaN      [Comedy, Drama, Romance]
# 4      Father of the Bride Collection                      [Comedy]
# ...                               ...                           ...
# 45460                             NaN      [Drama, Action, Romance]
# 45462                             NaN                       [Drama]
# 45463                             NaN     [Action, Drama, Thriller]
# 45464                             NaN                            []
# 45465                             NaN                            []
#
#                           production_companies_extracted  \
# 0                              [Pixar Animation Studios]
# 1      [TriStar Pictures, Teitler Film, Interscope Co...
# 2                         [Warner Bros., Lancaster Gate]
# 3               [Twentieth Century Fox Film Corporation]
# 4           [Sandollar Productions, Touchstone Pictures]
# ...                                                  ...
# 45460  [Westdeutscher Rundfunk (WDR), Working Title F...
# 45462                                      [Sine Olivia]
# 45463                          [American World Pictures]
# 45464                                        [Yermoliev]
# 45465                                                 []
#
#                           production_countries_extracted  languages_extracted  \
# 0                             [United States of America]            [English]
# 1                             [United States of America]  [English, Français]
# 2                             [United States of America]            [English]
# 3                             [United States of America]            [English]
# 4                             [United States of America]            [English]
# ...                                                  ...                  ...
# 45460  [Canada, Germany, United Kingdom, United State...            [English]
# 45462                                      [Philippines]                   []
# 45463                         [United States of America]            [English]
# 45464                                           [Russia]                   []
# 45465                                   [United Kingdom]            [English]
#
#        release_year
# 0              1995
# 1              1995
# 2              1995
# 3              1995
# 4              1995
# ...             ...
# 45460          1991
# 45462          2011
# 45463          2003
# 45464          1917
# 45465          2017
#
# [45376 rows x 20 columns]

# %%
# Convert the 'revenue' and 'budget' columns to numeric type
df_unested['revenue'] = pd.to_numeric(df_unested['revenue'], errors='coerce')
df_unested['budget'] = pd.to_numeric(df_unested['budget'], errors='coerce')

# Fill the null values in 'revenue' and 'budget' with 0
df_unested['revenue'].fillna(0, inplace=True)
df_unested['budget'].fillna(0, inplace=True)

# Calculate the return on investment (return) as revenue / budget
df_unested['return'] = df_unested['revenue'] / df_unested['budget']

# Replace infinite or indeterminate values with 0
df_unested['return'].replace([float('inf'), float('-inf'), float('nan')], 0, inplace=True)

# %%
df_unested
# Out:
#          budget      id original_language  \
# 0      30000000     862                en
# 1      65000000    8844                en
# 2             0   15602                en
# 3      16000000   31357                en
# 4             0   11862                en
# ...         ...     ...               ...
# 45460         0   30840                en
# 45462         0  111109                tl
# 45463         0   67758                en
# 45464         0  227506                en
# 45465         0  461257                en
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#       release_date      revenue  runtime    status  \
# 0       1995-10-30  373554033.0     81.0  Released
# 1       1995-12-15  262797249.0    104.0  Released
# 2       1995-12-22          0.0    101.0  Released
# 3       1995-12-22   81452156.0    127.0  Released
# 4       1995-02-10   76578911.0    106.0  Released
# ...            ...          ...      ...       ...
# 45460   1991-05-13          0.0    104.0  Released
# 45462   2011-11-17          0.0    360.0  Released
# 45463   2003-08-01          0.0     90.0  Released
# 45464   1917-10-21          0.0     87.0  Released
# 45465   2017-06-09          0.0     75.0  Released
#
#                                                  tagline  ... vote_average  \
# 0                                                    NaN  ...          7.7
# 1              Roll the dice and unleash the excitement!  ...          6.9
# 2      Still Yelling. Still Fighting. Still Ready for...  ...          6.5
# 3      Friends are the people who let you be yourself...  ...          6.1
# 4      Just When His World Is Back To Normal... He's ...  ...          5.7
# ...                                                  ...  ...          ...
# 45460                                                NaN  ...          5.7
# 45462                                                NaN  ...          9.0
# 45463                             A deadly game of wits.  ...          3.8
# 45464                                                NaN  ...          0.0
# 45465                                                NaN  ...          0.0
#
#        vote_count  collection_id                 collection_name  \
# 0          5415.0        10194.0            Toy Story Collection
# 1          2413.0            NaN                             NaN
# 2            92.0       119050.0       Grumpy Old Men Collection
# 3            34.0            NaN                             NaN
# 4           173.0        96871.0  Father of the Bride Collection
# ...           ...            ...                             ...
# 45460        26.0            NaN                             NaN
# 45462         3.0            NaN                             NaN
# 45463         6.0            NaN                             NaN
# 45464         0.0            NaN                             NaN
# 45465         0.0            NaN                             NaN
#
#                    genres_extracted  \
# 0       [Animation, Comedy, Family]
# 1      [Adventure, Fantasy, Family]
# 2                 [Romance, Comedy]
# 3          [Comedy, Drama, Romance]
# 4                          [Comedy]
# ...                             ...
# 45460      [Drama, Action, Romance]
# 45462                       [Drama]
# 45463     [Action, Drama, Thriller]
# 45464                            []
# 45465                            []
#
#                           production_companies_extracted  \
# 0                              [Pixar Animation Studios]
# 1      [TriStar Pictures, Teitler Film, Interscope Co...
# 2                         [Warner Bros., Lancaster Gate]
# 3               [Twentieth Century Fox Film Corporation]
# 4           [Sandollar Productions, Touchstone Pictures]
# ...                                                  ...
# 45460  [Westdeutscher Rundfunk (WDR), Working Title F...
# 45462                                      [Sine Olivia]
# 45463                          [American World Pictures]
# 45464                                        [Yermoliev]
# 45465                                                 []
#
#                           production_countries_extracted  languages_extracted  \
# 0                             [United States of America]            [English]
# 1                             [United States of America]  [English, Français]
# 2                             [United States of America]            [English]
# 3                             [United States of America]            [English]
# 4                             [United States of America]            [English]
# ...                                                  ...                  ...
# 45460  [Canada, Germany, United Kingdom, United State...            [English]
# 45462                                      [Philippines]                   []
# 45463                         [United States of America]            [English]
# 45464                                           [Russia]                   []
# 45465                                   [United Kingdom]            [English]
#
#       release_year     return
# 0             1995  12.451801
# 1             1995   4.043035
# 2             1995   0.000000
# 3             1995   5.090760
# 4             1995   0.000000
# ...            ...        ...
# 45460         1991   0.000000
# 45462         2011   0.000000
# 45463         2003   0.000000
# 45464         1917   0.000000
# 45465         2017   0.000000
#
# [45376 rows x 21 columns]

# %%
df_unested.drop_duplicates(subset="id", inplace=True)
